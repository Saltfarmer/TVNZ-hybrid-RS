# %%
import pandas as pd
from faker import Faker
import random

# %%
fake = Faker()
id = []
name = []
username = []
birthdate = []
job = []
sex = []

# %%
fake.profile()
# Out:
# {'job': 'Research scientist (physical sciences)',
#  'company': 'Soto Group',
#  'ssn': '840-46-5029',
#  'residence': '3508 James Mountains Suite 667\nCourtneyview, MS 62216',
#  'current_location': (Decimal('15.299028'), Decimal('-157.769058')),
#  'blood_group': 'O-',
#  'website': ['http://mejia.com/',
#   'https://www.boyd.info/',
#   'http://www.miller-singh.info/'],
#  'username': 'youngmaurice',
#  'name': 'Melissa Jenkins',
#  'sex': 'F',
#  'address': '281 Johnson Pass\nStephanieport, OK 54593',
#  'mail': 'fhale@gmail.com',
#  'birthdate': datetime.date(1963, 10, 19)}

# %%
fake.date_of_birth(minimum_age = 18)
# Out:
# datetime.date(1971, 1, 20)

# %%
for i in range(101):
    id.append(i)
    name.append(fake.profile()['name'])
    username.append(fake.profile()['username'])
    birthdate.append(fake.date_of_birth(minimum_age = 18))
    job.append(fake.profile()['job'])
    sex.append(fake.profile()['sex'])

# %%
len(sex)
# Out:
# 101

# %%
from datetime import date

def calculate_age(born):
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
calculate_age(birthdate[6])
# Out:
# 42

# %%
user_data = pd.DataFrame()

# %%
user_data['ID'] = id
user_data['name'] = name
user_data['username'] = username
user_data['birthdate'] = birthdate
user_data['job'] = job
user_data['sex'] = sex
user_data
# Out:
#       ID              name       username   birthdate  \
# 0      0     Bradley Russo       rbennett  1968-11-08
# 1      1      Brian Duncan        cindy96  1924-11-11
# 2      2         Jack Neal       daniel14  1922-06-06
# 3      3    Jasmine Harris     brianwhite  1972-04-12
# 4      4  Lisa Patrick DDS  websterashley  1980-11-01
# ..   ...               ...            ...         ...
# 96    96    Denise Jenkins         kclark  1924-07-01
# 97    97   Deborah Sweeney        cathy96  1998-01-23
# 98    98     Daniel Becker   travisandrew  1921-07-11
# 99    99     Jacob Roberts      barbara29  1971-10-30
# 100  100      Robert Lewis         havila  1984-12-18
#
#                                  job sex
# 0                           Best boy   F
# 1    Runner, broadcasting/film/video   F
# 2      Designer, television/film set   F
# 3                     Energy manager   F
# 4                Marketing executive   F
# ..                               ...  ..
# 96             Engineer, maintenance   F
# 97                   Ophthalmologist   F
# 98           Communications engineer   M
# 99                 Therapist, sports   F
# 100                 Technical author   M
#
# [101 rows x 6 columns]

# %%
user_data.to_csv("user_data.csv", index=False)

# %%
user_data
# Out:
#       ID              name       username   birthdate  \
# 0      0     Bradley Russo       rbennett  1968-11-08
# 1      1      Brian Duncan        cindy96  1924-11-11
# 2      2         Jack Neal       daniel14  1922-06-06
# 3      3    Jasmine Harris     brianwhite  1972-04-12
# 4      4  Lisa Patrick DDS  websterashley  1980-11-01
# ..   ...               ...            ...         ...
# 96    96    Denise Jenkins         kclark  1924-07-01
# 97    97   Deborah Sweeney        cathy96  1998-01-23
# 98    98     Daniel Becker   travisandrew  1921-07-11
# 99    99     Jacob Roberts      barbara29  1971-10-30
# 100  100      Robert Lewis         havila  1984-12-18
#
#                                  job sex
# 0                           Best boy   F
# 1    Runner, broadcasting/film/video   F
# 2      Designer, television/film set   F
# 3                     Energy manager   F
# 4                Marketing executive   F
# ..                               ...  ..
# 96             Engineer, maintenance   F
# 97                   Ophthalmologist   F
# 98           Communications engineer   M
# 99                 Therapist, sports   F
# 100                 Technical author   M
#
# [101 rows x 6 columns]

# %%
content_data = pd.read_csv("TVNZ_movies_v3.csv")

# %%
content_data
# Out:
#       ID                                           title  \
# 0      0                                Smoke & Mirrors
# 1      1                                           Dede
# 2      2                              The Soul of Flies
# 3      3           The Unauthorised Melrose Place Story
# 4      4  Stolen By My Mother: The Kamiyah Mobley Story
# ..   ...                                             ...
# 147  147  Gone Mom: The Disappearance of Jennifer Dulos
# 148  148                                   Good Manners
# 149  149                                        Beaches
# 150  150                                        Resolve
# 151  151                                       Homesick
#
#                                            description  \
# 0    The true story of a man who fooled an entire c...
# 1    A young woman living in a remote mountain vill...
# 2    A tale of two brothers who meet for the first ...
# 3    Discover the drama that went on behind the cam...
# 4    Based on the true story, an 18-year-old girl f...
# ..                                                 ...
# 147  Based on the true story of Jennifer Dulos, a w...
# 148  Clara, a lonely nurse from the outskirts of Sã...
# 149  An update to a classic tear-jerker, we witness...
# 150  Based on the true story of Chris Crean, who to...
# 151  An ambitious cellist is invited to represent G...
#
#                                                    tag  \
# 0    genre:drama/crime-thriller,genre:drama,genre:d...
# 1    genre:drama,genre:drama/foreign-language-subti...
# 2    genre:movie,genre:drama/foreign-language-subti...
# 3    genre:movie,genre:closed-captions,genre:drama,...
# 4    genre:movie,genre:drama,genre:drama/real-life-...
# ..                                                 ...
# 147  genre:movie,genre:drama/real-life-stories,genr...
# 148  genre:drama/crime-thriller,genre:drama,genre:d...
# 149  genre:movie,genre:drama,genre:closed-captions,...
# 150  genre:movie,genre:drama,genre:drama/real-life-...
# 151  genre:drama,genre:drama/foreign-language-subti...
#
#                                                  image  \
# 0    https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 1    https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 2    https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 3    https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 4    https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# ..                                                 ...
# 147  https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 148  https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 149  https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 150  https://play-images-prod-ctf.tech.tvnz.co.nz/a...
# 151  https://play-images-prod-ctf.tech.tvnz.co.nz/a...
#
#                                                   path  \
# 0    /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 1    /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 2    /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 3    /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 4    /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# ..                                                 ...
# 147  /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 148  /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 149  /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 150  /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
# 151  /Users/xutingxuan/Desktop/MSc ADS/B3_Personali...
#
#                                                  genre  \
# 0    crime-thriller, drama, foreign-language-subtit...
# 1    drama, foreign-language-subtitled, movie, real...
# 2            movie, foreign-language-subtitled, comedy
# 3    movie, closed-captions, drama, real-life-stori...
# 4                      movie, drama, real-life-stories
# ..                                                 ...
# 147    movie, real-life-stories, drama, crime-thriller
# 148  crime-thriller, drama, foreign-language-subtit...
# 149                      movie, drama, closed-captions
# 150  movie, drama, real-life-stories, sunday-theatr...
# 151           drama, foreign-language-subtitled, movie
#
#                                          mood distributor branded-vod  \
# 0                       thrilling, mysterious      rialto  filmstream
# 1                    revealing, all-the-feels      rialto  filmstream
# 2                  quirky, irreverent, cheeky      rialto  filmstream
# 3                    nostalgic, all-the-feels         a-e    lifetime
# 4                                     diverse         a-e    lifetime
# ..                                        ...         ...         ...
# 147      mysterious, thrilling, all-the-feels         a-e    lifetime
# 148          mysterious, scary, all-the-feels      rialto  filmstream
# 149  all-the-feels, nostalgic, warm-and-fuzzy         a-e    lifetime
# 150                                   diverse  screentime         NaN
# 151                  psychological, thrilling      rialto  filmstream
#
#      k_means  k_genre        GenreType Language  Local
# 0          3        0         Thriller  Spanish      0
# 1          3        1            Drama  English      0
# 2          3        1            Drama  Spanish      0
# 3          5        2  Real Life Story  English      0
# 4          2        2  Real Life Story  English      0
# ..       ...      ...              ...      ...    ...
# 147        2        0         Thriller  English      0
# 148        3        1            Drama  English      0
# 149        4        3          Romance  English      0
# 150        6        2  Real Life Story  English      0
# 151        3        1            Drama   German      0
#
# [152 rows x 15 columns]

# %%
rating = []
comment = []
user_id = []
content_id = []

for _ in range(15000):
    rating.append(random.randint(1,5))
    comment.append(fake.paragraph(nb_sentences = 5))
    user_id.append(random.randint(0, max(user_data.ID)))
    content_id.append(random.randint(0, max(content_data.ID)))

# %%
rating_data = pd.DataFrame()
rating_data['rating'] = rating
rating_data['comment'] = comment
rating_data['user_id'] = user_id
rating_data['content_id'] = content_id
rating_data
# Out:
#        rating                                            comment  user_id  \
# 0           5  Could star pattern activity radio author. Risk...       79
# 1           5  Owner phone animal. Computer manager during na...        1
# 2           3  Remain result I not tonight any particular. In...       46
# 3           1  Your then step during little sense. Expert wai...       21
# 4           4  Body culture large word sure feeling. Half wil...       75
# ...       ...                                                ...      ...
# 14995       2  Recent take month scientist page artist bed. G...       52
# 14996       4  Movie either risk add forget bank agent. Trade...       81
# 14997       1  Hit attorney forward study. Speak protect blue...       64
# 14998       2  Business care or change structure teacher. Spe...       57
# 14999       5  Group yes community go attorney even along. On...       95
#
#        content_id
# 0             119
# 1             121
# 2              81
# 3              51
# 4              92
# ...           ...
# 14995          31
# 14996          84
# 14997          15
# 14998         130
# 14999          94
#
# [15000 rows x 4 columns]

# %%
rating_data.to_csv("rating_data.csv", index=False)

# %%
combine = content_data.merge(rating_data.merge(user_data, left_on=['user_id'], right_on=['ID']), left_on=['ID'], right_on=['content_id'] )

# %%
combine['content_id'].value_counts().head()
# Out:
# 0      125
# 141    122
# 45     121
# 119    120
# 127    118
# Name: content_id, dtype: int64
